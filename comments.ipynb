# %% [markdown]
# A single frame 2D CNN has neiether temporal understanding or temporal shift invariance. We need to add sequences so the model understands motion and we also need the model to track motion changes for temporal shift invariance s.t. the model does not care when the motion happens, just how it happens. There are several ways to implement these features:
#
# ![image.png](attachment:image.png)
